# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
np.set_printoptions(precision=4)

# %%
X = np.random.randn(2,50) + 1
X = X * [[1],[0.1]]

# %%
fig, ax = plt.subplots()
ax.scatter(X[0],X[1])
ax.grid()
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.axis('equal')
plt.show()

# %%
u = np.mean(X, axis=1, keepdims=True)
X = X - u

# %%
fig, ax = plt.subplots()
ax.scatter(X[0],X[1])
ax.grid()
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.axis('equal')
plt.show()

# %%
o = np.square(X)
o = np.sum(o, axis=1, keepdims=True)
o = o / X.shape[1]
#o = np.sqrt(o)
print(o)
print(tf.math.reduce_variance(X,axis=1))
X = X / o
# Out:
# [[0.8203]
#  [0.0114]]
# tf.Tensor([0.8203 0.0114], shape=(2,), dtype=float64)

# %%
fig, ax = plt.subplots()
ax.scatter(X[0],X[1])
ax.grid()
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
plt.xlim(-5,5)
plt.ylim(-5,5)
ax.set_aspect('equal', adjustable='box')
plt.show()

# %%
n = np.square(X)
n = np.sum(n, axis=1, keepdims=True)
n = np.sqrt(n)
X = X / n

# %%
fig, ax = plt.subplots()
ax.scatter(X[0],X[1])
ax.grid()
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
plt.xlim(-1,1)
plt.ylim(-1,1)
ax.set_aspect('equal', adjustable='box')
plt.show()

# %%
print(np.sqrt(np.sum(np.square(X), axis=1, keepdims=True)))

# %%
Y = np.random.rand(1,20) * 20
print(Y.shape)
print(Y)

# %%
u = np.mean(Y,axis=1)
Y = Y - u
print(np.mean(Y,axis=1))
print(Y)

# %%
sigma = np.square(Y)
sigma = np.sum(sigma, axis=1)
sigma = sigma / Y.shape[1]
sigma = np.sqrt(sigma)
Y = Y / sigma
print(sigma)
print(Y)

# %%
sigma = np.square(Y)
sigma = np.sum(sigma, axis=1)
sigma = sigma / 20
sigma = np.sqrt(sigma)
print(sigma)
